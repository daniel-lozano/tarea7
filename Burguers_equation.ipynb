# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
n_x=100
n_t=100

nu=0.07

dx=2*math.pi/n_x
#dt=1.0/n_t
dt=nu*dx
#condicion: dx/dt
alpha=dt/dx

print dt/dx

x=linspace(0,2*math.pi,n_x)
u=zeros(n_x)
# Out:
# 0.07

# %%
for i in range(n_x):
    u[i]=sin(x[i])+2

# %%
plot(x,u,"ro",label="condiciones inciales")
xlabel("espacio")
ylabel("U")
legend()

# %%
u_past=ones(n_x)
u_past1=u.copy()


for i in range(n_t):
    
   u_past=u.copy()
    
   for i in range(1,n_x-1):
        
    #u[i]=alpha*u_past[i]*(u_past[i+1]-u_past[i])+alpha*(nu/dx)*(u_past[i+1]-2*u_past[i]+u_past[i-1])+u_past[i]
    
     u[i]= alpha* (u_past[i]*-(u_past[i]-u_past[i-1])+ nu*(u_past[i+1]-2*u_past[i]+u_past[i-1])/dx)  + u_past[i]

# %%
plot(x,u,"bo",label="condicion final")

plot(x,u_past1,"r",label="condicion inicial")

xlabel("posicion")

ylabel("U")
legend()
plt.show()
plt.close()
plot(x,u,label="condicion final")
